# %% [markdown]
# # EDA:World Happiness Report

# %%
# Clean and Wrangle Data
import numpy as np 
import pandas as pd

# %%
import pylab as pl
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Loading the datasets
data_2020=pd.read_csv(r"C:\Users\sahee\archive\2020.csv")
data_2021=pd.read_csv(r"C:\Users\sahee\archive\2021.csv")
data_2022=pd.read_csv(r"C:\Users\sahee\archive\2022.csv")

# %% [markdown]
# # Viewing head data for 2020,2021 and 2022

# %%
data_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
data_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
data_2022.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
print(data_2020.columns)
print("nn")
print(data_2021.columns)
print("nn")
print(data_2022.columns)
print("nn")
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')
# nn
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
# ...

# %%
print("Number of null or missing values in 2020 data: ",data_2020.isnull().sum().sum())
print("Number of null or missing values in 2021 data: ",data_2021.isnull().sum().sum())
print("Number of null or missing values in 2022 data: ",data_2022.isnull().sum().sum())
# Out:
# Number of null or missing values in 2020 data:  0
# Number of null or missing values in 2021 data:  0
# Number of null or missing values in 2022 data:  0

# %%
print("No. of countries ranked in 2020: ", len(data_2020))
print("No. of countries ranked in 2021: ", len(data_2021))
print("No. of countries ranked in 2022: ", len(data_2022))
# Out:
# No. of countries ranked in 2020:  153
# No. of countries ranked in 2021:  149
# No. of countries ranked in 2022:  146

# %% [markdown]
# # Data Visualization and Analysis

# %%
# analyzing the top-ranked country in 2020, 2021, and 2022 
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
# ...

# %%
data_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
data_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        146 non-null    int64
#  1   Country                                     146 non-null    object
#  2   Happiness score                             146 non-null    object
#  3   Whisker-high                                146 non-null    object
#  4   Whisker-low                                 146 non-null    object
#  5   Dystopia (1.83) + residual                  146 non-null    object
#  6   Explained by: GDP per capita                146 non-null    object
#  7   Explained by: Social support                146 non-null    object
#  8   Explained by: Healthy life expectancy       146 non-null    object
#  9   Explained by: Freedom to make life choices  146 non-null    object
# ...

# %%
print("Average happiness score of Finland is ", (data_2020['Ladder score'].iat[0]+data_2021['Ladder score'].iat[0])/2)
# Out:
# Average happiness score of Finland is  7.8253500425

# %%
# analysis unhappiness country
print("Most unphappiest Country in 2020: ", data_2020['Country name'].iat[-1], "(", data_2020['Ladder score'].iat[-1], ')')
print("Most unphappiest Country in 2021: ", data_2021['Country name'].iat[-1], "(", data_2021['Ladder score'].iat[-1], ')')
print("Most unphappiest Country in 2022: ", data_2022['Country'].iat[-1], "(", data_2022['Happiness score'].iat[-1], ')')
# Out:
# Most unphappiest Country in 2020:  Afghanistan ( 2.566900015 )
# Most unphappiest Country in 2021:  Afghanistan ( 2.523 )
# Most unphappiest Country in 2022:  Afghanistan ( 2,404 )

# %%
# Happiness rankings of nations in 2022
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)
data = dict(type = 'choropleth', 
           locations = data_2022['Country'],
           locationmode = 'country names',
           z = data_2022['RANK'], 
           text = data_2022['Country'],
           colorbar = {'title':'Happiness'})
layout = dict(title = 'Global Happiness 2022', 
             geo = dict(showframe = False))
choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# Country rankings based on GDP per capita
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)
data = dict(type = 'choropleth', 
           locations = data_2022['Country'],
           locationmode = 'country names',
           z = data_2022['Explained by: GDP per capita'], 
           text = data_2022['Country'],
           colorbar = {'title':'GDP per capita'})
layout = dict(title = 'GDP per capita in 2022', 
             geo = dict(showframe = False))
choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# Country rankings based on Healthy life expectancy 
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)

data = dict(type = 'choropleth', 
           locations = data_2022['Country'],
           locationmode = 'country names',
           z = data_2022['Explained by: Healthy life expectancy'], 
           text = data_2022['Country'],
           colorbar = {'title':'Healthy life expectancy'})
layout = dict(title = 'Healthy life expectancy in 2022', 
             geo = dict(showframe = False))
choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
print("Average life expectancy in 2020: ",data_2020['Healthy life expectancy'].mean())
print("Average life expectancy in 2021: ",data_2021['Healthy life expectancy'].mean())
print("Average life expectancy in 2022: ",data_2020['Explained by: Healthy life expectancy'].mean()*100)
# Out:
# Average life expectancy in 2020:  64.44552916509804
# Average life expectancy in 2021:  64.99279865771811
# Average life expectancy in 2022:  69.28690722091504

# %%
# During the COVID-19 pandemic, the average and minimum life span were 65 and 47, respectively
sorted_2020 = data_2020.sort_values('Healthy life expectancy')[0:5]
sorted_2021 = data_2021.sort_values('Healthy life expectancy')[0:5]
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.barplot(x='Country name',
            y="Healthy life expectancy", data=sorted_2020)
plt.subplot(1,2,2)
sns.barplot(x='Country name',
            y="Healthy life expectancy", data=sorted_2021)
# Out:
# <Axes: xlabel='Country name', ylabel='Healthy life expectancy'>

# %%
#  Country ranking based on Social support
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)

data = dict(type = 'choropleth', 
           locations = data_2022['Country'],
           locationmode = 'country names',
           z = data_2022['Explained by: Social support'], 
           text = data_2022['Country'],
           colorbar = {'title':'Social support'})
layout = dict(title = 'Social support in 2022', 
             geo = dict(showframe = False))
choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# Country rankings based on Generosity
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)
data = dict(type = 'choropleth', 
           locations = data_2022['Country'],
           locationmode = 'country names',
           z = data_2022['Explained by: Generosity'], 
           text = data_2022['Country'],
           colorbar = {'title':'Generosity'})
layout = dict(title = 'Generosity in 2022', 
             geo = dict(showframe = False))
choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# Country rankings based on Perceptions of corruption 
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)
data = dict(type = 'choropleth', 
           locations = data_2022['Country'],
           locationmode = 'country names',
           z = data_2022['Explained by: Perceptions of corruption'], 
           text = data_2022['Country'],
           colorbar = {'title':'Perceptions of corruption'})
layout = dict(title = 'Perceptions of corruption in 2022', 
             geo = dict(showframe = False))
choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# Analysis of relations among the happiness factors 
plt.figure(figsize=(24,8))
plt.subplot(1,3,1)
plt.scatter( data_2020['Ladder score'], data_2020['Logged GDP per capita'])
plt.scatter( data_2021['Ladder score'], data_2021['Logged GDP per capita'])
plt.xlabel('Logged GDP per capita in 2020 and 2021')
plt.ylabel('Happiness score')
plt.legend(['2020','2021'])

plt.subplot(1,3,2)
plt.scatter( data_2020['Ladder score'], data_2020['Social support'])
plt.scatter( data_2021['Ladder score'], data_2021['Social support'])
plt.xlabel('Social support in 2020 and 2021')
plt.ylabel('Happiness score')
plt.legend(['2020','2021'])

plt.subplot(1,3,3)
plt.scatter( data_2020['Ladder score'], data_2020['Healthy life expectancy'])
plt.scatter( data_2021['Ladder score'], data_2021['Healthy life expectancy'])
plt.xlabel('Healthy life expectancy in 2020 and 2021')
plt.ylabel('Happiness score')
plt.legend(['2020','2021'])

plt.figure(figsize=(24,8))
plt.subplot(1,3,1)
plt.scatter( data_2020['Ladder score'], data_2020['Freedom to make life choices'])
plt.scatter( data_2021['Ladder score'], data_2021['Freedom to make life choices'])
plt.xlabel('Freedom to make life choices in 2020 and 2021')
plt.ylabel('Happiness score')
plt.legend(['2020','2021'])
plt.subplot(1,3,2)
plt.scatter( data_2020['Ladder score'], data_2020['Generosity'])
plt.scatter( data_2021['Ladder score'], data_2021['Generosity'])
plt.xlabel('Generosity in 2020 and 2021')
plt.ylabel('Happiness score')
plt.legend(['2020','2021'])
plt.subplot(1,3,3)
plt.scatter( data_2020['Ladder score'], data_2020['Perceptions of corruption'])
plt.scatter( data_2021['Ladder score'], data_2021['Perceptions of corruption'])
plt.xlabel('Perceptions of corruption in 2020 and 2021')
plt.ylabel('Happiness score')
plt.legend(['2020','2021'])

# %%
correlations_2020 = data_2020[['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
                                 'Freedom to make life choices', 'Generosity','Perceptions of corruption',
                                 'Dystopia + residual']]
sns.pairplot(correlations_2020, kind='reg')

# %%
correlations_2021 = data_2020[['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
'Freedom to make life choices', 'Generosity','Perceptions of corruption',
'Dystopia + residual']]
sns.pairplot(correlations_2021, kind='reg')
